# %%
import tensorflow as tf
# NumPy is often used to load, manipulate and preprocess data.
import numpy as np

# Declare list of features. We only have one numeric feature. There are many
# other types of columns that are more complicated and useful.
feature_columns = [tf.feature_column.numeric_column("x", shape=[1])]

# An estimator is the front end to invoke training (fitting) and evaluation
# (inference). There are many predefined types like linear regression,
# linear classification, and many neural network classifiers and regressors.
# The following code provides an estimator that does linear regression.
estimator = tf.estimator.LinearRegressor(feature_columns=feature_columns)

# TensorFlow provides many helper methods to read and set up data sets.
# Here we use two data sets: one for training and one for evaluation
# We have to tell the function how many batches
# of data (num_epochs) we want and how big each batch should be.
x_train = np.array([1., 2., 3., 4.])
y_train = np.array([0., -1., -2., -3.])
x_eval = np.array([2., 5., 8., 1.])
y_eval = np.array([-1.01, -4.1, -7, 0.])
input_fn = tf.estimator.inputs.numpy_input_fn(
    {"x": x_train}, y_train, batch_size=4, num_epochs=None, shuffle=True)
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    {"x": x_train}, y_train, batch_size=4, num_epochs=1000, shuffle=False)
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    {"x": x_eval}, y_eval, batch_size=4, num_epochs=1000, shuffle=False)

# We can invoke 1000 training steps by invoking the  method and passing the
# training data set.
estimator.train(input_fn=input_fn, steps=2000)

# Here we evaluate how well our model did.
train_metrics = estimator.evaluate(input_fn=train_input_fn)
eval_metrics = estimator.evaluate(input_fn=eval_input_fn)
print("train metrics: %r"% train_metrics)
print("eval metrics: %r"% eval_metrics)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpc3jvy82b
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_tf_random_seed': 1, '_model_dir': '/tmp/tmpc3jvy82b', '_save_summary_steps': 100, '_save_checkpoints_secs': 600}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpc3jvy82b/model.ckpt.
# INFO:tensorflow:loss = 14.0, step = 1
# INFO:tensorflow:global_step/sec: 528.021
# INFO:tensorflow:loss = 0.225696, step = 101 (0.195 sec)
# INFO:tensorflow:global_step/sec: 419.983
# INFO:tensorflow:loss = 0.0457511, step = 201 (0.238 sec)
# INFO:tensorflow:global_step/sec: 489.046
# INFO:tensorflow:loss = 0.00122359, step = 301 (0.204 sec)
# INFO:tensorflow:global_step/sec: 476.573
# INFO:tensorflow:loss = 0.00314248, step = 401 (0.209 sec)
# INFO:tensorflow:global_step/sec: 491.842
# INFO:tensorflow:loss = 0.000334044, step = 501 (0.202 sec)
# INFO:tensorflow:global_step/sec: 479.149
# INFO:tensorflow:loss = 3.7444e-05, step = 601 (0.208 sec)
# INFO:tensorflow:global_step/sec: 498.378
# INFO:tensorflow:loss = 2.40982e-06, step = 701 (0.201 sec)
# INFO:tensorflow:global_step/sec: 492.897
# INFO:tensorflow:loss = 3.01924e-06, step = 801 (0.204 sec)
# INFO:tensorflow:global_step/sec: 435.698
# INFO:tensorflow:loss = 4.42143e-07, step = 901 (0.229 sec)
# INFO:tensorflow:global_step/sec: 530.822
# INFO:tensorflow:loss = 1.51179e-07, step = 1001 (0.189 sec)
# INFO:tensorflow:global_step/sec: 495.172
# INFO:tensorflow:loss = 1.7411e-08, step = 1101 (0.202 sec)
# INFO:tensorflow:global_step/sec: 501.37
# INFO:tensorflow:loss = 4.05391e-09, step = 1201 (0.201 sec)
# INFO:tensorflow:global_step/sec: 440.19
# INFO:tensorflow:loss = 8.21519e-10, step = 1301 (0.225 sec)
# INFO:tensorflow:global_step/sec: 542.352
# INFO:tensorflow:loss = 2.82238e-10, step = 1401 (0.184 sec)
# INFO:tensorflow:global_step/sec: 491.698
# INFO:tensorflow:loss = 3.64686e-11, step = 1501 (0.203 sec)
# INFO:tensorflow:global_step/sec: 466.464
# INFO:tensorflow:loss = 4.22062e-12, step = 1601 (0.215 sec)
# INFO:tensorflow:global_step/sec: 454.184
# INFO:tensorflow:loss = 4.54747e-13, step = 1701 (0.219 sec)
# INFO:tensorflow:global_step/sec: 500.817
# INFO:tensorflow:loss = 1.03029e-12, step = 1801 (0.200 sec)
# INFO:tensorflow:global_step/sec: 796.598
# INFO:tensorflow:loss = 5.11591e-13, step = 1901 (0.124 sec)
# INFO:tensorflow:Saving checkpoints for 2000 into /tmp/tmpc3jvy82b/model.ckpt.
# INFO:tensorflow:Loss for final step: 4.83169e-13.
# INFO:tensorflow:Starting evaluation at 2017-09-21-09:57:20
# INFO:tensorflow:Restoring parameters from /tmp/tmpc3jvy82b/model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-09-21-09:57:22
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 1.20792e-13, global_step = 2000, loss = 4.83169e-13
# INFO:tensorflow:Starting evaluation at 2017-09-21-09:57:22
# INFO:tensorflow:Restoring parameters from /tmp/tmpc3jvy82b/model.ckpt-2000
# INFO:tensorflow:Finished evaluation at 2017-09-21-09:57:23
# INFO:tensorflow:Saving dict for global step 2000: average_loss = 0.00252507, global_step = 2000, loss = 0.0101003
# train metrics: {'loss': 4.8316906e-13, 'global_step': 2000, 'average_loss': 1.2079227e-13}
# eval metrics: {'loss': 0.010100275, 'global_step': 2000, 'average_loss': 0.0025250688}

# %%
import numpy as np
import tensorflow as tf

# Declare list of features, we only have one real-valued feature
def model_fn(features, labels, mode):
  # Build a linear model and predict values
  W = tf.get_variable("W", [1], dtype=tf.float64)
  b = tf.get_variable("b", [1], dtype=tf.float64)
  y = W * features['x'] + b
  # Loss sub-graph
  loss = tf.reduce_sum(tf.square(y - labels))
  # Training sub-graph
  global_step = tf.train.get_global_step()
  optimizer = tf.train.GradientDescentOptimizer(0.01)
  train = tf.group(optimizer.minimize(loss),
                   tf.assign_add(global_step, 1))
  # EstimatorSpec connects subgraphs we built to the
  # appropriate functionality.
  return tf.estimator.EstimatorSpec(
      mode=mode,
      predictions=y,
      loss=loss,
      train_op=train)

estimator = tf.estimator.Estimator(model_fn=model_fn)
# define our data sets
x_train = np.array([1., 2., 3., 4.])
y_train = np.array([0., -1., -2., -3.])
x_eval = np.array([2., 5., 8., 1.])
y_eval = np.array([-1.01, -4.1, -7, 0.])
input_fn = tf.estimator.inputs.numpy_input_fn(
    {"x": x_train}, y_train, batch_size=4, num_epochs=None, shuffle=True)
train_input_fn = tf.estimator.inputs.numpy_input_fn(
    {"x": x_train}, y_train, batch_size=4, num_epochs=1000, shuffle=False)
eval_input_fn = tf.estimator.inputs.numpy_input_fn(
    {"x": x_eval}, y_eval, batch_size=4, num_epochs=1000, shuffle=False)

# train
estimator.train(input_fn=input_fn, steps=1000)
# Here we evaluate how well our model did.
train_metrics = estimator.evaluate(input_fn=train_input_fn)
eval_metrics = estimator.evaluate(input_fn=eval_input_fn)
print("train metrics: %r"% train_metrics)
print("eval metrics: %r"% eval_metrics)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpsdnm0y91
# INFO:tensorflow:Using config: {'_save_checkpoints_steps': None, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_keep_checkpoint_max': 5, '_session_config': None, '_tf_random_seed': 1, '_model_dir': '/tmp/tmpsdnm0y91', '_save_summary_steps': 100, '_save_checkpoints_secs': 600}
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpsdnm0y91/model.ckpt.
# INFO:tensorflow:loss = 9.85315286822, step = 1
# INFO:tensorflow:global_step/sec: 468.345
# INFO:tensorflow:loss = 0.0385818481983, step = 101 (0.219 sec)
# INFO:tensorflow:global_step/sec: 477.978
# INFO:tensorflow:loss = 0.000705721644398, step = 201 (0.209 sec)
# INFO:tensorflow:global_step/sec: 493.495
# INFO:tensorflow:loss = 0.000351475507367, step = 301 (0.202 sec)
# INFO:tensorflow:global_step/sec: 484.666
# INFO:tensorflow:loss = 4.14498255204e-06, step = 401 (0.208 sec)
# INFO:tensorflow:global_step/sec: 278.059
# INFO:tensorflow:loss = 2.8607645661e-06, step = 501 (0.359 sec)
# INFO:tensorflow:global_step/sec: 494.617
# INFO:tensorflow:loss = 2.6980162337e-07, step = 601 (0.200 sec)
# INFO:tensorflow:global_step/sec: 489.683
# INFO:tensorflow:loss = 4.1439960031e-08, step = 701 (0.203 sec)
# INFO:tensorflow:global_step/sec: 439.763
# INFO:tensorflow:loss = 2.13679900503e-09, step = 801 (0.227 sec)
# INFO:tensorflow:global_step/sec: 517.973
# INFO:tensorflow:loss = 1.49663544378e-10, step = 901 (0.193 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into /tmp/tmpsdnm0y91/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.46665239627e-11.
# INFO:tensorflow:Starting evaluation at 2017-09-21-09:58:19
# INFO:tensorflow:Restoring parameters from /tmp/tmpsdnm0y91/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-21-09:58:21
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 1.28857e-11
# INFO:tensorflow:Starting evaluation at 2017-09-21-09:58:21
# INFO:tensorflow:Restoring parameters from /tmp/tmpsdnm0y91/model.ckpt-1000
# INFO:tensorflow:Finished evaluation at 2017-09-21-09:58:23
# INFO:tensorflow:Saving dict for global step 1000: global_step = 1000, loss = 0.0101004
# train metrics: {'loss': 1.2885706e-11, 'global_step': 1000}
# eval metrics: {'loss': 0.010100366, 'global_step': 1000}
