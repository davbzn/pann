# %%
import Oger
import numpy as np
from sklearn.datasets import make_moons
import matplotlib.pyplot as plt
import mdp

# %%
resnode = Oger.nodes.ReservoirNode(output_dim = 100)

# %%
readoutnode = Oger.nodes.RidgeRegressionNode()

# %%
flow = resnode + readoutnode

# %%
x,y = Oger.datasets.narma30()

# %%
data = [None, zip(x[0:-1],y[0:-1])]

# %%
flow.train(data)

# %%
plt.plot(flow(x[-1]))
plt.plot(y[-1])

plt.show()

# %%
gridsearch_parameters = {resnode:{'input_scaling': mdp.numx.arange(0.1, 0.5, 0.1)}}

# %%
opt = Oger.evaluation.Optimizer(gridsearch_parameters, Oger.utils.nrmse)
opt.grid_search(data, flow, cross_validate_function=Oger.evaluation.n_fold_random, n_folds=5)
# Out:
#   0% ? - ?
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-7e0408f8d240> in <module>()
#       1 opt = Oger.evaluation.Optimizer(gridsearch_parameters, Oger.utils.nrmse)
# ----> 2 opt.grid_search(data, flow, cross_validate_function=Oger.evaluation.n_fold_random, n_folds=5)
#
# /usr/local/lib/python2.7/dist-packages/Oger/evaluation/optimizer.pyc in grid_search(self, data, flow, cross_validate_function, progress, validation_suffix_flow, internal_gridsearch_parameters, *args, **kwargs)
#      95                                                          progress=False, internal_gridsearch_parameters=internal_gridsearch_parameters,
#      96                                                          validation_suffix_flow=validation_suffix_flow,
# ---> 97                                                          *args, **kwargs)
#      98
#      99             if internal_gridsearch_parameters is not None:
#
# /usr/local/lib/python2.7/dist-packages/Oger/evaluation/model_validation.pyc in validate(data, flow, error_measure, cross_validate_function, progress, internal_gridsearch_parameters, validation_suffix_flow, error_aggregation_function, *args, **kwargs)
#      91     test_error = []
#      92
# ---> 93     for validate_gen_result in validate_gen(data, flow, cross_validate_function, internal_gridsearch_parameters, error_measure, progress, validation_suffix_flow, *args, **kwargs):
#      94         if internal_gridsearch_parameters is not None:
#      95             f_copy, _, test_sample_list, f_untrained = validate_gen_result
#
# /usr/local/lib/python2.7/dist-packages/Oger/evaluation/model_validation.pyc in validate_gen(data, flow, cross_validate_function, internal_gridsearch_parameters, error_measure, progress, validation_suffix_flow, *args, **kwargs)
#     137     '''
#     138     # Get the number of samples
# --> 139     n_samples = mdp.numx.amax(map(len, data))
#     140
#     141     # Get the indices of the training and testing samples for each fold by calling the
#
# TypeError: object of type 'NoneType' has no len()
