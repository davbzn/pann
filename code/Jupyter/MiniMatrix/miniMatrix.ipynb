# %%
# plotting libraries
import matplotlib
import matplotlib.pyplot as plt 
# numpy (math) libary
import numpy as np

# data dictionary
d = {}

# %%
# Use LaTeX to manage text layout
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
#################################################
######             MINI MATRIX             ######

folder = 'data/'
date1 = '2017-11-07'
date2 = '2017-11-08'
#date3 = '2017-11-09'
#date4 = '2017-11-10'

path1 = folder+date1+'/'+date1
path2 = folder+date2+'/'+date2
#path3 = folder+date3+'/'+date3
#path4 = folder+date4+'/'+date4
#path5 = folder+date5+'/'+date5

# %%
#################################################
######            STRUCTURE M1             ######

# Read CSV files:
# input 1, output 1
d['M1i1o1_lowG'] = np.loadtxt(path1+'_M1i1o1_P2mW_deg14_wlen1527-1557-0.05_lowG.tsv')
d['M1i1o1'] = np.loadtxt(path1+'_M1i1o1_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 2
d['M1i1o2'] = np.loadtxt(path1+'_M1i1o2_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 3
d['M1i1o3'] = np.loadtxt(path1+'_M1i1o3_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')
d['M1i1o3_2'] = np.loadtxt(path1+'_M1i1o3_P2mW_deg14_wlen1527-1557-0.05_medG_2.tsv')

# input 1, output 4
d['M1i1o4'] = np.loadtxt(path1+'_M1i1o4_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 5
d['M1i1o5'] = np.loadtxt(path1+'_M1i1o5_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')
d['M1i1o5_2'] = np.loadtxt(path1+'_M1i1o5_P2mW_deg14_wlen1527-1557-0.05_medG_2.tsv')

# input 1, output 6
d['M1i1o6'] = np.loadtxt(path1+'_M1i1o6_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 7
d['M1i1o7'] = np.loadtxt(path1+'_M1i1o7_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 8
d['M1i1o8'] = np.loadtxt(path1+'_M1i1o8_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')
d['M1i1o8_2'] = np.loadtxt(path1+'_M1i1o8_P2mW_deg14_wlen1527-1557-0.05_medG_2.tsv')

# input 1, output 9
d['M1i1o9'] = np.loadtxt(path1+'_M1i1o9_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')
d['M1i1o9_wide1'] = np.loadtxt(path1+'_M1i1o9_P2mW_deg14_wlen1500-1570_lowG.tsv')
d['M1i1o9_wide2'] = np.loadtxt(path1+'_M1i1o9_P2mW_deg14_wlen1505-1575-0.05_lowG.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

#ax1.plot(d['M1i1o1_lowG'][:,0], 10*np.log10(d['M1i1o1_lowG'][:,2]), label='1st output') # less consistent than medG
ax1.plot(d['M1i1o1'][:,0], 10*np.log10(d['M1i1o1'][:,2]), label='1st output')

ax1.plot(d['M1i1o2'][:,0], 10*np.log10(d['M1i1o2'][:,2]), label='2nd output')

ax1.plot(d['M1i1o3'][:,0], 10*np.log10(d['M1i1o3'][:,2]), label='3rd output')
#ax1.plot(d['M1i1o3_2'][:,0], 10*np.log10(d['M1i1o3_2'][:,2]), label='3rd output, 2') # one or the other

ax1.plot(d['M1i1o4'][:,0], 10*np.log10(d['M1i1o4'][:,2]), label='4th output')

ax1.plot(d['M1i1o5'][:,0], 10*np.log10(d['M1i1o5'][:,2]), label='5th output')
#ax1.plot(d['M1i1o5_2'][:,0], 10*np.log10(d['M1i1o5_2'][:,2]), label='5th output, 2') # one or the other

ax1.plot(d['M1i1o6'][:,0], 10*np.log10(d['M1i1o6'][:,2]), label='6th output')

ax1.plot(d['M1i1o7'][:,0], 10*np.log10(d['M1i1o7'][:,2]), label='7th output')

#ax1.plot(d['M1i1o8'][:,0], 10*np.log10(d['M1i1o8'][:,2]), label='8th output') # BAD DATA
ax1.plot(d['M1i1o8_2'][:,0], 10*np.log10(d['M1i1o8_2'][:,2]), label='8th output')

ax1.plot(d['M1i1o9'][:,0], 10*np.log10(d['M1i1o9'][:,2]), label='Truth output')
#ax1.plot(d['M1i1o9_wide1'][:,0], 10*np.log10(d['M1i1o9_wide1'][:,2]), label='Truth output, wide1')
#ax1.plot(d['M1i1o9_wide2'][:,0], 10*np.log10(d['M1i1o9_wide2'][:,2]), label='Truth output, wide2')

ax1.set_title( r'MiniMatrix M1, 1st-to-8th output channels and truth channel', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

x  = d['M1i1o1'][:,0]
y  = d['M1i1o1'][:,2]+d['M1i1o2'][:,2]+d['M1i1o3'][:,2]+d['M1i1o4'][:,2]+d['M1i1o5'][:,2]
y += d['M1i1o6'][:,2]+d['M1i1o7'][:,2]+d['M1i1o8_2'][:,2]+d['M1i1o9'][:,2]

ax1.plot(x, 10*np.log10(y), label='Sum of all outputs')

ax1.plot(d['M1i1o9'][:,0], 10*np.log10(d['M1i1o9'][:,2]), label='Truth output')

ax1.set_title(r'MiniMatrix M1, truth channel and sum of all output channels', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
er = ['\tdr_%d'%(x+1) for x in range(8)]
head = 'output'
for x in er:
    head += x
head += '\tth'
print(head)

datt = np.column_stack((np.array(d['M1i1o1'][:,0]),
                        np.array(d['M1i1o1'][:,2]),
                        np.array(d['M1i1o2'][:,2]),
                        np.array(d['M1i1o3'][:,2]),
                        np.array(d['M1i1o4'][:,2]),
                        np.array(d['M1i1o5'][:,2]),
                        np.array(d['M1i1o6'][:,2]),
                        np.array(d['M1i1o7'][:,2]),
                        np.array(d['M1i1o8_2'][:,2]),
                        np.array(d['M1i1o9'][:,2])
                       ))
print(datt.shape)
np.savetxt("M1.csv", datt, fmt='%.8e', delimiter="\t", header=head, comments='')#, newline=' \\')
# Out:
# output	dr_1	dr_2	dr_3	dr_4	dr_5	dr_6	dr_7	dr_8	th
# (600, 10)

# %%
#################################################
######            STRUCTURE M2             ######

# Read CSV files:
# input 1, output 1
d['M2i1o1'] = np.loadtxt(path1+'_M2i1o1_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 2
d['M2i1o2'] = np.loadtxt(path1+'_M2i1o2_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 3
d['M2i1o3'] = np.loadtxt(path1+'_M2i1o3_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 4
d['M2i1o4'] = np.loadtxt(path1+'_M2i1o4_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 5
d['M2i1o5'] = np.loadtxt(path1+'_M2i1o5_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 6
d['M2i1o6'] = np.loadtxt(path1+'_M2i1o6_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 7
d['M2i1o7'] = np.loadtxt(path1+'_M2i1o7_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 8
d['M2i1o8'] = np.loadtxt(path1+'_M2i1o8_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 9
d['M2i1o9'] = np.loadtxt(path1+'_M2i1o9_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')
d['M2i1o9_2'] = np.loadtxt(path1+'_M2i1o9_P2mW_deg14_wlen1527-1557-0.05_medG_2.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M2i1o1'][:,0], 10*np.log10(d['M2i1o1'][:,2]), label='1st output')

ax1.plot(d['M2i1o2'][:,0], 10*np.log10(d['M2i1o2'][:,2]), label='2nd output')

ax1.plot(d['M2i1o3'][:,0], 10*np.log10(d['M2i1o3'][:,2]), label='3rd output')

ax1.plot(d['M2i1o4'][:,0], 10*np.log10(d['M2i1o4'][:,2]), label='4th output')

ax1.plot(d['M2i1o5'][:,0], 10*np.log10(d['M2i1o5'][:,2]), label='5th output')

ax1.plot(d['M2i1o6'][:,0], 10*np.log10(d['M2i1o6'][:,2]), label='6th output')

ax1.plot(d['M2i1o7'][:,0], 10*np.log10(d['M2i1o7'][:,2]), label='7th output')

ax1.plot(d['M2i1o8'][:,0], 10*np.log10(d['M2i1o8'][:,2]), label='8th output')

ax1.plot(d['M2i1o9'][:,0], 10*np.log10(d['M2i1o9'][:,2]), label='Truth output')
ax1.plot(d['M2i1o9_2'][:,0], 10*np.log10(d['M2i1o9_2'][:,2]), label='Truth output, 2')

ax1.set_title( r'MiniMatrix M2, 1st-to-8th output channels and truth channel', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

x  = d['M2i1o1'][:,0]
y  = d['M2i1o1'][:,2]+d['M2i1o2'][:,2]+d['M2i1o3'][:,2]+d['M2i1o4'][:,2]+d['M2i1o5'][:,2]
y += d['M2i1o6'][:,2]+d['M2i1o7'][:,2]+d['M2i1o8'][:,2]+d['M2i1o9'][:,2]

y2  = d['M2i1o1'][:,2]+d['M2i1o2'][:,2]+d['M2i1o3'][:,2]+d['M2i1o4'][:,2]+d['M2i1o5'][:,2]
y2 += d['M2i1o6'][:,2]+d['M2i1o7'][:,2]+d['M2i1o8'][:,2]+d['M2i1o9_2'][:,2]

yavg  = d['M2i1o1'][:,2]+d['M2i1o2'][:,2]+d['M2i1o3'][:,2]+d['M2i1o4'][:,2]+d['M2i1o5'][:,2]
yavg += d['M2i1o6'][:,2]+d['M2i1o7'][:,2]+d['M2i1o8'][:,2]+0.5*d['M2i1o9'][:,2]+0.5*d['M2i1o9_2'][:,2]

#ax1.plot(x, 10*np.log10(y), label='Sum of all outputs')

#ax1.plot(x, 10*np.log10(y2), label='Sum of all outputs, 2')

ax1.plot(x, 10*np.log10(yavg), label='Sum of all outputs, avg')

#ax1.plot(d['M2i1o9'][:,0], 10*np.log10(d['M2i1o9'][:,2]), label='Truth output')
ax1.plot(0.5*d['M2i1o9'][:,0]+0.5*d['M2i1o9_2'][:,0], 10*np.log10(0.5*d['M2i1o9'][:,2]+0.5*d['M2i1o9_2'][:,2]), label='Truth output')

ax1.set_title(r'MiniMatrix M2, truth channel and sum of all output channels', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
er = ['\tdr_%d'%(x+1) for x in range(8)]
head = 'output'
for x in er:
    head += x
head += '\tth'
print(head)

datt = np.column_stack((np.array(d['M2i1o1'][:,0]),
                        np.array(d['M2i1o1'][:,2]),
                        np.array(d['M2i1o2'][:,2]),
                        np.array(d['M2i1o3'][:,2]),
                        np.array(d['M2i1o4'][:,2]),
                        np.array(d['M2i1o5'][:,2]),
                        np.array(d['M2i1o6'][:,2]),
                        np.array(d['M2i1o7'][:,2]),
                        np.array(d['M2i1o8'][:,2]),
                        np.array(d['M2i1o9'][:,2])
                       ))
print(datt.shape)
np.savetxt("M2.csv", datt, fmt='%.8e', delimiter="\t", header=head, comments='')#, newline=' \\')
# Out:
# output	dr_1	dr_2	dr_3	dr_4	dr_5	dr_6	dr_7	dr_8	th
# (600, 10)

# %%
#################################################
######            STRUCTURE M3             ######

# Read CSV files:
# input 1, output 1
d['M3i1o1'] = np.loadtxt(path2+'_M3i1o1_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 2
d['M3i1o2'] = np.loadtxt(path2+'_M3i1o2_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 3
d['M3i1o3'] = np.loadtxt(path2+'_M3i1o3_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 4
d['M3i1o4'] = np.loadtxt(path2+'_M3i1o4_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 5
d['M3i1o5'] = np.loadtxt(path2+'_M3i1o5_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 6
d['M3i1o6'] = np.loadtxt(path2+'_M3i1o6_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 7
d['M3i1o7'] = np.loadtxt(path2+'_M3i1o7_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 8
d['M3i1o8'] = np.loadtxt(path2+'_M3i1o8_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# input 1, output 9
d['M3i1o9'] = np.loadtxt(path2+'_M3i1o9_P2mW_deg14_wlen1527-1557-0.05_medG.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3i1o1'][:,0], 10*np.log10(d['M3i1o1'][:,2]), label='1st output')

ax1.plot(d['M3i1o2'][:,0], 10*np.log10(d['M3i1o2'][:,2]), label='2nd output')

ax1.plot(d['M3i1o3'][:,0], 10*np.log10(d['M3i1o3'][:,2]), label='3rd output')

ax1.plot(d['M3i1o4'][:,0], 10*np.log10(d['M3i1o4'][:,2]), label='4th output')

ax1.plot(d['M3i1o5'][:,0], 10*np.log10(d['M3i1o5'][:,2]), label='5th output')

ax1.plot(d['M3i1o6'][:,0], 10*np.log10(d['M3i1o6'][:,2]), label='6th output')

ax1.plot(d['M3i1o7'][:,0], 10*np.log10(d['M3i1o7'][:,2]), label='7th output')

ax1.plot(d['M3i1o8'][:,0], 10*np.log10(d['M3i1o8'][:,2]), label='8th output')

ax1.plot(d['M3i1o9'][:,0], 10*np.log10(d['M3i1o9'][:,2]), label='Truth output')

ax1.set_title( r'MiniMatrix M3, 1st-to-8th output channels and truth channel', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

x  = d['M3i1o1'][:,0]
y  = d['M3i1o1'][:,2]+d['M3i1o2'][:,2]+d['M3i1o3'][:,2]+d['M3i1o4'][:,2]+d['M3i1o5'][:,2]
y += d['M3i1o6'][:,2]+d['M3i1o7'][:,2]+d['M3i1o8'][:,2]+d['M3i1o9'][:,2]

ax1.plot(x, 10*np.log10(y), label='Sum of all outputs')

ax1.plot(d['M3i1o9'][:,0], 10*np.log10(d['M3i1o9'][:,2]), label='Truth output')

ax1.set_title(r'MiniMatrix M3, truth channel and sum of all output channels', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

x  = d['M3i1o1'][496:512,0]
y  = d['M3i1o1'][496:512,2]

ax1.plot(x, 10*np.log10(y), label='Sum of all outputs')

ax1.set_title(r'MiniMatrix M3, 1st output channel', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
er = ['\tdr_%d'%(x+1) for x in range(8)]
head = 'output'
for x in er:
    head += x
head += '\tth'
print(head)

datt = np.column_stack((np.array(d['M3i1o1'][:,0]),
                        np.array(d['M3i1o1'][:,2]),
                        np.array(d['M3i1o2'][:,2]),
                        np.array(d['M3i1o3'][:,2]),
                        np.array(d['M3i1o4'][:,2]),
                        np.array(d['M3i1o5'][:,2]),
                        np.array(d['M3i1o6'][:,2]),
                        np.array(d['M3i1o7'][:,2]),
                        np.array(d['M3i1o8'][:,2]),
                        np.array(d['M3i1o9'][:,2])
                       ))
print(datt.shape)
np.savetxt("M3.csv", datt, fmt='%.8e', delimiter="\t", header=head, comments='')#, newline=' \\')
# Out:
# output	dr_1	dr_2	dr_3	dr_4	dr_5	dr_6	dr_7	dr_8	th
# (600, 10)

# %%
#################################################
######            STRUCTURE M3             ######

# Read CSV files:
# output 1, Pump power 0 mW
d['M3o1P0'] = np.loadtxt(path2+'_M3-i1o1_T2mW-P0mW_wlen1542-1562-0.05_lowG.tsv')

# output 1, Pump power 12.7 dBm
d['M3o1P13'] = np.loadtxt(path2+'_M3-i1o1_T2mW-P12.7dBm_wlen1542-1562-0.05_lowG.tsv')

# output 1, Pump power 17.4 dBm
d['M3o1P17'] = np.loadtxt(path2+'_M3-i1o1_T2mW-P17.4dBm_wlen1542-1562-0.05_lowG.tsv')

# output 1, Pump power 22.0 dBm
d['M3o1P22'] = np.loadtxt(path2+'_M3-i1o1_T2mW-P22.0dBm_wlen1542-1562-0.05_lowG.tsv')

# output 1, Pump power 24.4 dBm
d['M3o1P24'] = np.loadtxt(path2+'_M3-i1o1_T2mW-P24.4dBm_wlen1542-1562-0.05_lowG.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3i1o1'][:,0], 10*np.log10(d['M3i1o1'][:,2]), label='first output,\nno pump')

ax1.plot(d['M3o1P0'][:,0], 10*np.log10(d['M3o1P0'][:,2]), label='first output,\n0mW pump')
ax1.plot(d['M3o1P13'][:,0], 10*np.log10(d['M3o1P13'][:,2]), label='first output,\n12.7 dBm pump')
ax1.plot(d['M3o1P17'][:,0], 10*np.log10(d['M3o1P17'][:,2]), label='first output,\n17.4 dBm pump')
ax1.plot(d['M3o1P22'][:,0], 10*np.log10(d['M3o1P22'][:,2]), label='first output,\n22.0 dBm pump')
ax1.plot(d['M3o1P24'][:,0], 10*np.log10(d['M3o1P24'][:,2]), label='first output,\n24.4 dBm pump')

ax1.set_title(r'MiniMatrix M3, 1st output channel', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

#####

fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.set_xlim([1549, 1555])
ax1.set_ylim([-0.025, 0.05])

ax1.plot(d['M3i1o1'][:,0], d['M3i1o1'][:,2]-np.mean(d['M3i1o1'][:,2]), label='first output,\nno pump')

ax1.plot(d['M3o1P0'][:,0], d['M3o1P0'][:,2]-np.mean(d['M3o1P0'][:,2]), label='first output,\n0mW pump')
ax1.plot(d['M3o1P13'][:,0], d['M3o1P13'][:,2]-np.mean(d['M3o1P13'][:,2]), label='first output,\n12.7 dBm pump')
ax1.plot(d['M3o1P17'][:,0], d['M3o1P17'][:,2]-np.mean(d['M3o1P17'][:,2]), label='first output,\n17.4 dBm pump')
ax1.plot(d['M3o1P22'][:,0], d['M3o1P22'][:,2]-np.mean(d['M3o1P22'][:,2]), label='first output,\n22.0 dBm pump')
ax1.plot(d['M3o1P24'][:,0], d['M3o1P24'][:,2]-np.mean(d['M3o1P24'][:,2]), label='first output,\n24.4 dBm pump')

ax1.set_title(r'MiniMatrix M3, 1st output channel', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

######
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

x = np.array([0, np.power(10,1.27), np.power(10,1.74), np.power(10,2.2), np.power(10,2.4)])
y = [max(d['M3o1P0'][:,2])-np.mean(d['M3o1P0'][:,2]), max(d['M3o1P13'][:,2]) - np.mean(d['M3o1P13'][:,2]), max(d['M3o1P17'][:,2]) - np.mean(d['M3o1P17'][:,2]), max(d['M3o1P22'][:,2]) - np.mean(d['M3o1P22'][:,2]), max(d['M3o1P24'][:,2]) - np.mean(d['M3o1P24'][:,2])]

ax1.plot(x, y, label='peak output vs pump power in mW')

plt.show()
plt.close()

# %%
date3  = '2017-11-13'
path3s = folder+date3+'/'
path3  = folder+date3+'/'+date3

import glob

# %%
run1 = np.array([np.loadtxt(pathstr) for pathstr in glob.glob(path3s+'run1/*')])
run2 = np.array([np.loadtxt(pathstr) for pathstr in glob.glob(path3s+'run2/*')])
run3 = np.array([np.loadtxt(pathstr) for pathstr in glob.glob(path3s+'run3/*')])
run4 = np.array([np.loadtxt(pathstr) for pathstr in glob.glob(path3s+'run4/*')])

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

for ii in range(0,np.shape(run1)[0]):
    ax1.plot( run1[ii,:,0], 10*np.log10(run1[ii,:,1]), label='run1')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

#box = ax1.get_position()
#ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

#####

fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot( [ max(run1[ii,:,1]) for ii in range(0,np.shape(run1)[0]) ], label='run1', color='r')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Time [$10^1 s$]', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16, color='r')

ax2 = ax1.twinx()
ax2.plot( [ run1[ii,run1[ii,:,1]==max(run1[ii,:,1]),0] for ii in range(0,np.shape(run1)[0]) ], label='run1')

ax2.set_ylabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16, color='b')
ax2.tick_params('y')

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

for ii in range(0,np.shape(run2)[0]):
    ax1.plot( run2[ii,:,0], 10*np.log10(run2[ii,:,1]), label='run2')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

#box = ax1.get_position()
#ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot( [ max(run2[ii,:,1]) for ii in range(0,np.shape(run2)[0]) ], label='run2', color='r')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Time [$10^1 s$]', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16, color='b')

ax2 = ax1.twinx()
ax2.plot( [ run2[ii,run2[ii,:,1]==max(run2[ii,:,1]),0] for ii in range(0,np.shape(run2)[0]) ], label='run2')

ax2.set_ylabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16, color='b')
ax2.tick_params('y')

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

for ii in range(0,np.shape(run3)[0]):
    ax1.plot( run3[ii,:,0], 10*np.log10(run3[ii,:,1]), label='run3')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

#box = ax1.get_position()
#ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

#####

fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot( [ max(run3[ii,:,1]) for ii in range(0,np.shape(run3)[0]) ], label='run3', color='r')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Time [$10^1 s$]', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16, color='r')

ax2 = ax1.twinx()
ax2.plot( [ run3[ii,run3[ii,:,1]==max(run3[ii,:,1]),0] for ii in range(0,np.shape(run3)[0]) ], label='run3')

ax2.set_ylabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16, color='b')
ax2.tick_params('y')

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

for ii in range(0,np.shape(run4)[0]):
    ax1.plot( run4[ii,:,0], 10*np.log10(run4[ii,:,1]), label='run4')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[dBm]$', fontsize=16)

#box = ax1.get_position()
#ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

#legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

#####

fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot( [ max(run4[ii,:,1]) for ii in range(0,np.shape(run4)[0]) ], label='run4', color='r')

ax1.set_title(r'laser diode stability', fontsize=16)
ax1.set_xlabel(r'Time [$10^1 s$]', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16, color='r')

ax2 = ax1.twinx()
ax2.plot( [ run4[ii,run4[ii,:,1]==max(run4[ii,:,1]),0] for ii in range(0,np.shape(run4)[0]) ], label='run4')

ax2.set_ylabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16, color='b')
ax2.tick_params('y')

plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log10
#   """
