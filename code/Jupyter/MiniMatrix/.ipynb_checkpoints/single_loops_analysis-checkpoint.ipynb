# %%
# plotting libraries
import matplotlib
import matplotlib.pyplot as plt 
# numpy (math) libary
import numpy as np

from scipy import interpolate

path1 = '../../../data/2017_12_20/'
path2 = '../../../data/2017_12_22/'

# %%
m2a = np.loadtxt(path1+'1610-m2_andata.tsv')
m2r = np.loadtxt(path1+'1621-m2_discesa.tsv')
m2a.shape

m3a = np.loadtxt(path1+'1629-m3_andata.tsv')
m3r = np.loadtxt(path1+'1631-m3_discesa.tsv')

m4a = np.loadtxt(path1+'1633-m4_salita.tsv')
m4r = np.loadtxt(path1+'1632-m4_discesa.tsv')

m5a = np.loadtxt(path1+'1658-m5_salita.tsv')
m5r = np.loadtxt(path1+'1659-m5_discesa.tsv')

m6a = np.loadtxt(path1+'1701-m6_salita.tsv')
m6r = np.loadtxt(path1+'1702-m6_discesa.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)


ax1.plot(m2a[:,0],m2a[:,1], label='1552.30nm')
ax1.plot(m2r[:,0],m2r[:,1], label='1552.30nm', ls='--')

#ax1.plot(m3a[:,0],m3a[:,1], label='1552.37nm')
#ax1.plot(m3r[:,0],m3r[:,1], label='1552.37nm', ls='--')

#ax1.plot(m4a[:,0],m4a[:,1], label='1552.18nm')
#ax1.plot(m4r[:,0],m4r[:,1], label='1552.18nm', ls='--')

#ax1.plot(m5a[:,0],m5a[:,1], label='1552.24nm')
#ax1.plot(m5r[:,0],m5r[:,1], label='1552.24nm', ls='--')

#ax1.plot(m6a[:,0],m6a[:,1], label='1552.31nm')
#ax1.plot(m6r[:,0],m6r[:,1], label='1552.31nm', ls='--')

legend = ax1.legend(loc=2, fontsize=16)

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

k=1.2
ax1.plot(k*m2a[:,0],m2a[:,1], label='1552.30nm')
ax1.plot(k*m2r[:,0],m2r[:,1], label='1552.30nm', ls='--')

ax1.plot(m3a[:,0],m3a[:,1], label='1552.37nm')
ax1.plot(m3r[:,0],m3r[:,1], label='1552.37nm', ls='--')

ax1.plot(m4a[:,0],m4a[:,1], label='1552.18nm')
ax1.plot(m4r[:,0],m4r[:,1], label='1552.18nm', ls='--')

ax1.plot(m5a[:,0],m5a[:,1], label='1552.24nm')
ax1.plot(m5r[:,0],m5r[:,1], label='1552.24nm', ls='--')

ax1.plot(m6a[:,0],m6a[:,1], label='1552.31nm')
ax1.plot(m6r[:,0],m6r[:,1], label='1552.31nm', ls='--')

legend = ax1.legend(loc=2, fontsize=16)

plt.show()
plt.close()

# %%
cy1 = np.loadtxt(path2+'1139-VOA_sweep_2cy.tsv')
cy2 = np.loadtxt(path2+'1140-VOA_sweep_2cy.tsv')
cy3 = np.loadtxt(path2+'1142-VOA_sweep_2cy.tsv')
cy4 = np.loadtxt(path2+'1149-VOA_sweep_2cy.tsv')
cy5 = np.loadtxt(path2+'1150-VOA_sweep_2cy.tsv')
cy6 = np.loadtxt(path2+'1151-VOA_sweep_2cy.tsv')

cy7 = np.loadtxt(path2+'1203-VOA_sweep_10cy.tsv')
cy8 = np.loadtxt(path2+'1212-VOA_sweep_10cy.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)


ax1.plot( cy4[:,0], cy4[:,1], label='1')
ax1.plot( cy5[:,0], cy5[:,1], label='5')
ax1.plot( cy6[:,0], cy6[:,1], label='10')
ax1.plot( cy2[:,0], cy2[:,1], label='50')
ax1.plot( cy1[:,0], cy1[:,1], label='100')
ax1.plot( cy3[:,0], cy3[:,1], label='200')

ax1.plot( cy7[:,0], cy7[:,1], label='100')
ax1.plot( cy8[:,0], cy8[:,1], label='100')


legend = ax1.legend(loc=2, fontsize=16)

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot( cy7[:,0], cy7[:,1], label='Δλ~0.35nm, 10Hz sampling rate')

ax1.set_xlabel('Input Intensity [a.u.]', fontsize = 16)
ax1.set_ylabel('Output Intensity [a.u.]', fontsize = 16)
legend = ax1.legend(loc=2, fontsize=16)

plt.show()
plt.close()
