# %%
# plotting libraries
import matplotlib
import matplotlib.pyplot as plt 
# numpy (math) libary
import numpy as np

# data dictionary
d = {}

# %%
# Use LaTeX to manage text layout
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
#################################################
######             MINI MATRIX             ######

folder = 'data/'
date1 = '2017_11_20'
date2 = '2017_11_16'

path1 = folder+date1+'/'+date1
#path2 = folder+date2+'/'

# %%
#################################################
######            STRUCTURE M3             ######

# Read CSV files:
# Pump power ~10 mW + 24.5 dBm
d['M3P10_osa_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.6dBm-P10.22mW-OSA_scan.tsv')
d['M3P10_out_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.6dBm-P10.22mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P10_out_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.6dBm-P10.22mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P10_osa_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.6dBm-P10.22mW-OSA_scan-2.tsv')

# Pump power ~20 mW + 24.5 dBm
d['M3P20_osa_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.7dBm-P20.25mW-OSA_scan.tsv')
d['M3P20_out_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.7dBm-P20.25mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P20_out_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.7dBm-P20.25mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P20_osa_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.7dBm-P20.26mW-OSA_scan-2.tsv')

# Pump power ~30 mW + 24.5 dBm
d['M3P30_osa_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.7dBm-P30.38mW-OSA_scan.tsv')
d['M3P30_out_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P30.38mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P30_out_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P30.38mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P30_osa_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P30.28mW-OSA_scan-2.tsv')

# Pump power ~40 mW + 24.5 dBm
d['M3P40_osa_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P39.94mW-OSA_scan.tsv')
d['M3P40_out_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P39.94mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P40_out_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P39.94mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P40_osa_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P40.1mW-OSA_scan-2.tsv')

# Pump power ~50 mW + 24.5 dBm
d['M3P50_osa_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P49.99mW-OSA_scan.tsv')
d['M3P50_out_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P49.99mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P50_out_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P49.99mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P50_osa_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P50.21mW-OSA_scan-2.tsv')

# Pump power ~60 mW + 24.5 dBm
d['M3P60_osa_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P60.41mW-OSA_scan.tsv')
d['M3P60_out_1'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P60.41mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P60_out_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P60.41mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P60_osa_2'] = np.loadtxt(path1+'-M3-T1mW@1552.5+26.8dBm-P60.71mW-OSA_scan-2.tsv')

# Pump power ~01 mW
d['M3P01_osa_1'] = np.loadtxt(path1+'-M3-T4mW@1552.5-P0.92mW-OSA_scan.tsv')
d['M3P01_out_1'] = np.loadtxt(path1+'-M3-T4mW@1552.5-P0.92mW-wlen1550.5_1554.5_0.025.tsv')
d['M3P01_out_2'] = np.loadtxt(path1+'-M3-T4mW@1552.5-P0.92mW-wlen1550.5_1554.5_0.025-2.tsv')
d['M3P01_osa_2'] = np.loadtxt(path1+'-M3-T4mW@1552.5-P0.92mW-OSA_scan-2.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3P10_osa_1'][:,0],   d['M3P10_osa_1'][:,1],   label='pump ~10mW (OSA), 1', ls='-')
ax1.plot(d['M3P10_osa_2'][:,0],   d['M3P10_osa_2'][:,1],   label='pump ~10mW (OSA), 2', ls='--')
ax1.plot(d['M3P20_osa_1'][:,0],   d['M3P20_osa_1'][:,1],   label='pump ~20mW (OSA), 1', ls='-')
ax1.plot(d['M3P20_osa_2'][:,0],   d['M3P20_osa_2'][:,1],   label='pump ~20mW (OSA), 2', ls='--')
ax1.plot(d['M3P30_osa_1'][:,0],   d['M3P30_osa_1'][:,1],   label='pump ~30mW (OSA), 1', ls='-')
ax1.plot(d['M3P30_osa_2'][:,0],   d['M3P30_osa_2'][:,1],   label='pump ~30mW (OSA), 2', ls='--')
ax1.plot(d['M3P40_osa_1'][:,0],   d['M3P40_osa_1'][:,1],   label='pump ~40mW (OSA), 1', ls='-')
ax1.plot(d['M3P40_osa_2'][:,0],   d['M3P40_osa_2'][:,1],   label='pump ~40mW (OSA), 2', ls='--')
ax1.plot(d['M3P50_osa_1'][:,0],   d['M3P50_osa_1'][:,1],   label='pump ~50mW (OSA), 1', ls='-')
ax1.plot(d['M3P50_osa_2'][:,0],   d['M3P50_osa_2'][:,1],   label='pump ~50mW (OSA), 2', ls='--')
ax1.plot(d['M3P60_osa_1'][:,0],   d['M3P60_osa_1'][:,1],   label='pump ~60mW (OSA), 1', ls='-')
ax1.plot(d['M3P60_osa_2'][:,0],   d['M3P60_osa_2'][:,1],   label='pump ~60mW (OSA), 2', ls='--')
ax1.plot(d['M3P01_osa_1'][:,0],   d['M3P01_osa_1'][:,1],   label='pump ~01mW (OSA), 1', ls='-')
ax1.plot(d['M3P01_osa_2'][:,0],   d['M3P01_osa_2'][:,1],   label='pump ~01mW (OSA), 2', ls='--')


ax1.set_title( r'Tunics spectra, OSA', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

#ax1.set_ylim([-0.0125,0.2125])

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

print(d['M3P10_osa_1'][d['M3P10_osa_1'][:,1]==max(d['M3P10_osa_1'][:,1]),0],' nm,',max(d['M3P10_osa_1'][:,1]),'mW')
print(d['M3P10_osa_2'][d['M3P10_osa_2'][:,1]==max(d['M3P10_osa_2'][:,1]),0],' nm,',max(d['M3P10_osa_1'][:,1]),'mW')
print()
print(d['M3P20_osa_1'][d['M3P20_osa_1'][:,1]==max(d['M3P20_osa_1'][:,1]),0],' nm,',max(d['M3P20_osa_1'][:,1]),'mW')
print(d['M3P20_osa_2'][d['M3P20_osa_2'][:,1]==max(d['M3P20_osa_2'][:,1]),0],' nm,',max(d['M3P20_osa_1'][:,1]),'mW')
print()
print(d['M3P30_osa_1'][d['M3P30_osa_1'][:,1]==max(d['M3P30_osa_1'][:,1]),0],' nm,',max(d['M3P30_osa_1'][:,1]),'mW')
print(d['M3P30_osa_2'][d['M3P30_osa_2'][:,1]==max(d['M3P30_osa_2'][:,1]),0],' nm,',max(d['M3P30_osa_1'][:,1]),'mW')
print()
print(d['M3P40_osa_1'][d['M3P40_osa_1'][:,1]==max(d['M3P40_osa_1'][:,1]),0],' nm,',max(d['M3P40_osa_1'][:,1]),'mW')
print(d['M3P40_osa_2'][d['M3P40_osa_2'][:,1]==max(d['M3P40_osa_2'][:,1]),0],' nm,',max(d['M3P40_osa_1'][:,1]),'mW')
print()
print(d['M3P50_osa_1'][d['M3P50_osa_1'][:,1]==max(d['M3P50_osa_1'][:,1]),0],' nm,',max(d['M3P50_osa_1'][:,1]),'mW')
print(d['M3P50_osa_2'][d['M3P50_osa_2'][:,1]==max(d['M3P50_osa_2'][:,1]),0],' nm,',max(d['M3P50_osa_1'][:,1]),'mW')
print()
print(d['M3P60_osa_1'][d['M3P60_osa_1'][:,1]==max(d['M3P60_osa_1'][:,1]),0],' nm,',max(d['M3P60_osa_1'][:,1]),'mW')
print(d['M3P60_osa_2'][d['M3P60_osa_2'][:,1]==max(d['M3P60_osa_2'][:,1]),0],' nm,',max(d['M3P60_osa_1'][:,1]),'mW')
print()
print(d['M3P01_osa_1'][d['M3P01_osa_1'][:,1]==max(d['M3P01_osa_1'][:,1]),0],' nm,',max(d['M3P01_osa_1'][:,1]),'mW')
print(d['M3P01_osa_2'][d['M3P01_osa_2'][:,1]==max(d['M3P01_osa_2'][:,1]),0],' nm,',max(d['M3P01_osa_1'][:,1]),'mW')
# Out:
# [ 1552.132]  nm, 10.14 mW
# [ 1552.148]  nm, 10.14 mW
#
# [ 1552.144]  nm, 20.02 mW
# [ 1552.124]  nm, 20.02 mW
#
# [ 1552.124]  nm, 30.05 mW
# [ 1552.136  1552.14 ]  nm, 30.05 mW
#
# [ 1552.132  1552.136  1552.14 ]  nm, 39.89 mW
# [ 1552.132  1552.136  1552.14 ]  nm, 39.89 mW
#
# [ 1552.128]  nm, 49.74 mW
# [ 1552.128]  nm, 49.74 mW
#
# [ 1552.128]  nm, 59.75 mW
# [ 1552.116]  nm, 59.75 mW
#
# [ 1552.092  1552.096]  nm, 0.9092 mW
# [ 1552.104  1552.108]  nm, 0.9092 mW

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3P10_out_1'][:,0],   d['M3P10_out_1'][:,1],   label='pump ~10mW (out), 1', ls='-')
ax1.plot(d['M3P10_out_2'][:,0],   d['M3P10_out_2'][:,1],   label='pump ~10mW (out), 2', ls='--')
ax1.plot(d['M3P20_out_1'][:,0],   d['M3P20_out_1'][:,1],   label='pump ~20mW (out), 1', ls='-')
ax1.plot(d['M3P20_out_2'][:,0],   d['M3P20_out_2'][:,1],   label='pump ~20mW (out), 2', ls='--')
ax1.plot(d['M3P30_out_1'][:,0],   d['M3P30_out_1'][:,1],   label='pump ~30mW (out), 1', ls='-')
ax1.plot(d['M3P30_out_2'][:,0],   d['M3P30_out_2'][:,1],   label='pump ~30mW (out), 2', ls='--')
ax1.plot(d['M3P40_out_1'][:,0],   d['M3P40_out_1'][:,1],   label='pump ~40mW (out), 1', ls='-')
ax1.plot(d['M3P40_out_2'][:,0],   d['M3P40_out_2'][:,1],   label='pump ~40mW (out), 2', ls='--')
ax1.plot(d['M3P50_out_1'][:,0],   d['M3P50_out_1'][:,1],   label='pump ~50mW (out), 1', ls='-')
ax1.plot(d['M3P50_out_2'][:,0],   d['M3P50_out_2'][:,1],   label='pump ~50mW (out), 2', ls='--')
ax1.plot(d['M3P60_out_1'][:,0],   d['M3P60_out_1'][:,1],   label='pump ~60mW (out), 1', ls='-')
ax1.plot(d['M3P60_out_2'][:,0],   d['M3P60_out_2'][:,1],   label='pump ~60mW (out), 2', ls='--')
ax1.plot(d['M3P01_out_1'][:,0],   d['M3P01_out_1'][:,1],   label='pump ~01mW (out), 1', ls='-')
ax1.plot(d['M3P01_out_2'][:,0],   d['M3P01_out_2'][:,1],   label='pump ~01mW (out), 2', ls='--')


ax1.set_title( r'Tunics spectra, output power', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

#ax1.set_ylim([-0.0125,0.2125])

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()
