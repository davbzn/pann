# %%
# plotting libraries
import matplotlib
import matplotlib.pyplot as plt 
# numpy (math) libary
import numpy as np

# data dictionary
d = {}

# %%
# Use LaTeX to manage text layout
from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
rc('text', usetex=True)

# %%
#################################################
######             MINI MATRIX             ######

folder = 'data/'
date1 = '2017-11-15'
date2 = '2017-11-16'

path1 = folder+date1+'/'+date1
path2 = folder+date2+'/'

# %%
#################################################
######            STRUCTURE M3             ######

# Read CSV files:
# Pump power ~5 mW + 24.5 dBm
d['M3P5mW_a_pump']  = np.loadtxt(path1+'_M3_T2mW-P4.657mW+24.5dBm_OSA-scan.tsv')
d['M3P5mW_a_out']   = np.loadtxt(path1+'_M3-i1o1_T2mW-P4.657mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~12 mW + 24.5 dBm
d['M3P12mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P11.63mW+24.5dBm_OSA-scan.tsv')
d['M3P12mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P11.63mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~22 mW + 24.5 dBm
d['M3P22mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P21.96mW+24.5dBm_OSA-scan.tsv')
d['M3P22mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P21.96mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~22 mW + 24.5 dBm
d['M3P22mW_b_pump'] = np.loadtxt(path1+'_M3_T2mW-P21.92mW+24.5dBm_OSA-scan.tsv')
d['M3P22mW_b_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P21.92mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~36 mW + 24.5 dBm
d['M3P36mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P35.96mW+24.5dBm_OSA-scan.tsv')
d['M3P36mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P35.96mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~36 mW + 24.5 dBm
d['M3P36mW_b_pump'] = np.loadtxt(path1+'_M3_T2mW-P36.0mW+24.5dBm_OSA-scan.tsv')
d['M3P36mW_b_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P36.0mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~36 mW + 24.5 dBm
d['M3P36mW_c_pump'] = np.loadtxt(path1+'_M3_T2mW-P36.04mW+24.5dBm_OSA-scan.tsv')
d['M3P36mW_c_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P36.04mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~41 mW + 24.5 dBm
d['M3P41mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P40.94mW+24.5dBm_OSA-scan.tsv')
d['M3P41mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P40.94mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~42 mW + 24.5 dBm
d['M3P42mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P42.03mW+24.5dBm_OSA-scan.tsv')
d['M3P42mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P42.03mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~42 mW + 24.5 dBm
d['M3P42mW_b_pump'] = np.loadtxt(path1+'_M3_T2mW-P42.1mW+24.5dBm_OSA-scan.tsv')
d['M3P42mW_b_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P42.1mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~29 mW + 24.5 dBm
d['M3P29mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P29.34mW+24.5dBm_OSA-scan.tsv')
d['M3P29mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P29.34mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~25 mW + 24.5 dBm
d['M3P25mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P24.91mW+24.5dBm_OSA-scan.tsv')
d['M3P25mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P24.91mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~23 mW + 24.5 dBm
d['M3P23mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P23.14mW+24.5dBm_OSA-scan.tsv')
d['M3P23mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P23.14mW+24.5dBm_wlen1550-1554-0.01_lowG.tsv')

# Pump power ~10 mW + 24.6±0.1 dBm
d['M3P10mW_a_pump'] = np.loadtxt(path1+'_M3_T2mW-P9.739mW+24.5dBm_OSA-scan.tsv')
d['M3P10mW_a_out']  = np.loadtxt(path1+'_M3-i1o1_T2mW-P9.739mW+24.7dBm_wlen1550-1554-0.01_lowG.tsv')

# %%
print(max(d['M3P5mW_a_pump'][:,1]))
print(min(d['M3P5mW_a_out'][:,2]))
print(max(d['M3P5mW_a_pump'][:,1])/min(d['M3P5mW_a_out'][:,2]),'\n')
print(max(d['M3P12mW_a_pump'][:,1]))
print(min(d['M3P12mW_a_out'][:,2]))
print(max(d['M3P12mW_a_pump'][:,1])/min(d['M3P12mW_a_out'][:,2]),'\n')
print(max(d['M3P22mW_b_pump'][:,1]))
print(min(d['M3P22mW_b_out'][:,2]))
print(max(d['M3P22mW_b_pump'][:,1])/min(d['M3P22mW_b_out'][:,2]),'\n')
print(max(d['M3P25mW_a_pump'][:,1]))
print(min(d['M3P25mW_a_out'][:,2]))
print(max(d['M3P25mW_a_pump'][:,1])/min(d['M3P25mW_a_out'][:,2]),'\n')
print(max(d['M3P23mW_a_pump'][:,1]))
print(min(d['M3P23mW_a_out'][:,2]))
print(max(d['M3P23mW_a_pump'][:,1])/min(d['M3P23mW_a_out'][:,2]),'\n')
print(max(d['M3P10mW_a_pump'][:,1]))
print(min(d['M3P10mW_a_out'][:,2]))
print(max(d['M3P10mW_a_pump'][:,1])/min(d['M3P10mW_a_out'][:,2]),'\n')
factor_avg  = max(d['M3P5mW_a_pump'][:,1])/min(d['M3P5mW_a_out'][:,2])
factor_avg += max(d['M3P12mW_a_pump'][:,1])/min(d['M3P12mW_a_out'][:,2])
factor_avg += max(d['M3P22mW_b_pump'][:,1])/min(d['M3P22mW_b_out'][:,2])
factor_avg += max(d['M3P25mW_a_pump'][:,1])/min(d['M3P25mW_a_out'][:,2])
factor_avg += max(d['M3P23mW_a_pump'][:,1])/min(d['M3P23mW_a_out'][:,2])
factor_avg += max(d['M3P10mW_a_pump'][:,1])/min(d['M3P10mW_a_out'][:,2])
factor_avg  = factor_avg/6.0
print(factor_avg)
# Out:
# 4.657
# 0.098323
# 47.3642992992
#
# 11.66
# 0.247462
# 47.1183454429
#
# 21.92
# 0.46388
# 47.253600069
#
# 24.91
# 0.544088
# 45.7830350973
#
# 23.14
# 0.553632
# 41.7967169528
#
# 9.739
# 0.219848
# 44.2987882537
#
# 45.6024641858

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3P5mW_a_out'][:,0],  d['M3P5mW_a_out'][:,1]-max(d['M3P5mW_a_pump'][:,1])/factor_avg,  label='pump 5mW, rise', ls='-')
ax1.plot(d['M3P12mW_a_out'][:,0],  d['M3P12mW_a_out'][:,1]-max(d['M3P12mW_a_pump'][:,1])/factor_avg,  label='pump 12mW, rise', ls='-')
ax1.plot(d['M3P22mW_a_out'][:,0],  d['M3P22mW_a_out'][:,1]-max(d['M3P22mW_a_pump'][:,1])/factor_avg,  label='pump 22mW, rise, a', ls='-')
ax1.plot(d['M3P22mW_b_out'][:,0],  d['M3P22mW_b_out'][:,1]-max(d['M3P22mW_b_pump'][:,1])/factor_avg,  label='pump 22mW, rise, b', ls='-')
ax1.plot(d['M3P36mW_a_out'][:,0],  d['M3P36mW_a_out'][:,1]-max(d['M3P36mW_a_pump'][:,1])/factor_avg,  label='pump 36mW, rise, a', ls='-')
ax1.plot(d['M3P36mW_b_out'][:,0],  d['M3P36mW_b_out'][:,1]-max(d['M3P36mW_b_pump'][:,1])/factor_avg,  label='pump 36mW, rise, b', ls='-')
ax1.plot(d['M3P36mW_c_out'][:,0],  d['M3P36mW_c_out'][:,1]-max(d['M3P36mW_c_pump'][:,1])/factor_avg,  label='pump 36mW, rise, c', ls='-')
ax1.plot(d['M3P41mW_a_out'][:,0],  d['M3P41mW_a_out'][:,1]-max(d['M3P41mW_a_pump'][:,1])/factor_avg,  label='pump 41mW, rise', ls='-')
ax1.plot(d['M3P42mW_a_out'][:,0],  d['M3P42mW_a_out'][:,1]-max(d['M3P42mW_a_pump'][:,1])/factor_avg,  label='pump 42mW, rise, a', ls='-')
ax1.plot(d['M3P42mW_b_out'][:,0],  d['M3P42mW_b_out'][:,1]-max(d['M3P42mW_b_pump'][:,1])/factor_avg,  label='pump 42mW, rise, b', ls='-')
ax1.plot(d['M3P29mW_a_out'][:,0],  d['M3P29mW_a_out'][:,1]-max(d['M3P29mW_a_pump'][:,1])/factor_avg,  label='pump 29mW, rise', ls='-')
ax1.plot(d['M3P25mW_a_out'][:,0],  d['M3P25mW_a_out'][:,1]-max(d['M3P25mW_a_pump'][:,1])/factor_avg,  label='pump 25mW, rise', ls='-')
ax1.plot(d['M3P23mW_a_out'][:,0],  d['M3P23mW_a_out'][:,1]-max(d['M3P23mW_a_pump'][:,1])/factor_avg,  label='pump 23mW, rise', ls='-')
ax1.plot(d['M3P10mW_a_out'][:,0],  d['M3P10mW_a_out'][:,1]-max(d['M3P10mW_a_pump'][:,1])/factor_avg,  label='pump 10mW, rise', ls='-')

ax1.set_title( r'MiniMatrix M3, 1st output, nonlinearity analysis', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3P5mW_a_out'][:,0],  d['M3P5mW_a_out'][:,2],  label='out 5mW, rise', ls='-')
ax1.plot(d['M3P12mW_a_out'][:,0],  d['M3P12mW_a_out'][:,2],  label='out 12mW, rise', ls='-')
ax1.plot(d['M3P22mW_a_out'][:,0],  d['M3P22mW_a_out'][:,2],  label='out 22mW, rise, a', ls='-')
ax1.plot(d['M3P22mW_b_out'][:,0],  d['M3P22mW_b_out'][:,2],  label='out 22mW, rise, b', ls='-')
ax1.plot(d['M3P36mW_a_out'][:,0],  d['M3P36mW_a_out'][:,2],  label='out 36mW, rise, a', ls='-')
ax1.plot(d['M3P36mW_b_out'][:,0],  d['M3P36mW_b_out'][:,2],  label='out 36mW, rise, b', ls='-')
ax1.plot(d['M3P36mW_c_out'][:,0],  d['M3P36mW_c_out'][:,2],  label='out 36mW, rise, c', ls='-')
ax1.plot(d['M3P41mW_a_out'][:,0],  d['M3P41mW_a_out'][:,2],  label='out 41mW, rise', ls='-')
ax1.plot(d['M3P42mW_a_out'][:,0],  d['M3P42mW_a_out'][:,2],  label='out 42mW, rise, a', ls='-')
ax1.plot(d['M3P42mW_b_out'][:,0],  d['M3P42mW_b_out'][:,2],  label='out 42mW, rise, b', ls='-')
ax1.plot(d['M3P29mW_a_out'][:,0],  d['M3P29mW_a_out'][:,2],  label='out 29mW, rise', ls='-')
ax1.plot(d['M3P25mW_a_out'][:,0],  d['M3P25mW_a_out'][:,2],  label='out 25mW, rise', ls='-')
ax1.plot(d['M3P23mW_a_out'][:,0],  d['M3P23mW_a_out'][:,2],  label='out 23mW, rise', ls='-')
ax1.plot(d['M3P10mW_a_out'][:,0],  d['M3P10mW_a_out'][:,2],  label='out 10mW, rise', ls='-')

ax1.set_title( r'MiniMatrix M3, 1st output, nonlinearity analysis', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3P5mW_a_out'][:,0],  d['M3P5mW_a_out'][:,1]-min(d['M3P5mW_a_out'][:,1]),  label='out 5mW, rise', ls='-')
ax1.plot(d['M3P12mW_a_out'][:,0],  d['M3P12mW_a_out'][:,1]-min(d['M3P12mW_a_out'][:,1]),  label='out 12mW, rise', ls='-')
ax1.plot(d['M3P22mW_a_out'][:,0],  d['M3P22mW_a_out'][:,1]-min(d['M3P22mW_a_out'][:,1]),  label='out 22mW, rise, a', ls='-')
ax1.plot(d['M3P22mW_b_out'][:,0],  d['M3P22mW_b_out'][:,1]-min(d['M3P22mW_b_out'][:,1]),  label='out 22mW, rise, b', ls='-')
ax1.plot(d['M3P36mW_a_out'][:,0],  d['M3P36mW_a_out'][:,1]-min(d['M3P36mW_a_out'][:,1]),  label='out 36mW, rise, a', ls='-')
ax1.plot(d['M3P36mW_b_out'][:,0],  d['M3P36mW_b_out'][:,1]-min(d['M3P36mW_b_out'][:,1]),  label='out 36mW, rise, b', ls='-')
ax1.plot(d['M3P36mW_c_out'][:,0],  d['M3P36mW_c_out'][:,1]-min(d['M3P36mW_c_out'][:,1]),  label='out 36mW, rise, c', ls='-')
ax1.plot([], [], label='out 41mW, rise', ls='--')
ax1.plot([], [], label='out 42mW, rise, a', ls='--')
ax1.plot([], [], label='out 42mW, rise, b', ls='--')
ax1.plot([], [], label='out 29mW, rise', ls='--')
ax1.plot([], [], label='out 25mW, rise', ls='--')
ax1.plot([], [], label='out 23mW, rise', ls='--')
ax1.plot(d['M3P10mW_a_out'][:,0],  d['M3P10mW_a_out'][:,1]-min(d['M3P10mW_a_out'][:,1]),  label='out 10mW, rise', ls='--')

ax1.set_title( r'MiniMatrix M3, 1st output, nonlinearity analysis', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
#################################################
######            STRUCTURE M3             ######

# Read CSV files:
# first run
d['M3_r1s1_pump']  = np.loadtxt(path2+'2017-11-16_M3_T4mW-P43.95mW+24.7dBm_OSA-scan.tsv')
d['M3_r1s1_out']   = np.loadtxt(path2+'2017-11-16_M3-i1o1_T4mW-P43.95mW+24.7dBm_wlen1552-1556-0.01_lowG.tsv')

d['M3_r1s2_pump']  = np.loadtxt(path2+'2017-11-16_M3_T4mW-P42.86mW+24.7dBm_OSA-scan.tsv')
d['M3_r1s2_out']   = np.loadtxt(path2+'2017-11-16_M3-i1o1_T4mW-P42.86mW+24.7dBm_wlen1552-1556-0.01_lowG.tsv')

d['M3_r1s3_pump']  = np.loadtxt(path2+'2017-11-16_M3_T4mW-P42.92mW+24.7dBm_OSA-scan.tsv')
d['M3_r1s3_out']   = np.loadtxt(path2+'2017-11-16_M3-i1o1_T4mW-P42.92mW+24.7dBm_wlen1552-1556-0.01_lowG.tsv')

# second run
d['M3_r2_tunics1']    = np.loadtxt(path2+'h1400/'+'2017_11_16-T1mW-OSA_scan.tsv')
d['M3_r2_tunics2']    = np.loadtxt(path2+'h1400/'+'2017_11_16-T0.5mW-OSA_scan.tsv')
d['M3_r2_resonance1'] = np.loadtxt(path2+'h1400/'+'2017_11_16-M3_i1o1-T1mW-wlen1552_1556_0.01.tsv')
d['M3_r2_resonance2'] = np.loadtxt(path2+'h1400/'+'2017_11_16-M3_i1o1-T1mW-wlen1552_1556_0.01-2.tsv')
d['M3_r2_resonance3'] = np.loadtxt(path2+'h1400/'+'2017_11_16-M3_i1o1-T0.5mW-wlen1552_1556_0.01.tsv')
d['M3_r2_noise']      = np.loadtxt(path2+'h1400/'+'2017_11_16-M3_i1o1-T0-wlen1552_1556_0.01.tsv')

d['M3_r2s1_pump']     = np.loadtxt(path2+'h1400/'+'2017_11_16-M3-T0.5mW-P38.3mW+24.9dBm-OSA_scan.tsv')
d['M3_r2s1_out']      = np.loadtxt(path2+'h1400/'+'2017_11_16-M3-T0.5mW-P38.3mW+24.9dBm-wlen1552_1556_0.1.tsv')

d['M3_r2s1_pump-2']   = np.loadtxt(path2+'h1400/'+'2017_11_16-M3-T0.5mW-P38.2mW+24.8dBm-OSA_scan.tsv')
d['M3_r2s1_pump-3']   = np.loadtxt(path2+'h1400/'+'2017_11_16-M3-T0.5mW-P38.08mW+24.8dBm-OSA_scan.tsv')

d['M3_r2s2_out']      = np.loadtxt(path2+'h1400/'+'2017_11_16-M3-T0.5mW-P37.98mW+24.9dBm-wlen1552_1556_0.05.tsv')
d['M3_r2s2_pump']     = np.loadtxt(path2+'h1400/'+'2017_11_16-M3-T0.5mW-P37.98mW+24.9dBm-OSA_scan.tsv')

## is this valid data? answer: I don't know
d['M3_r2s3_out']      = np.loadtxt(path2+'h1400/'+'2017-11-16_M3-i1o1_T4mW-P42.86mW+24.7dBm_wlen1552-1556-0.01_lowG.tsv')

# third run
d['M3_r3s1_out']      = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T0.5mW-P40ishmW+27.6dBm-wlen1552_1556_0.025.tsv')
d['M3_r3s1_out-2']    = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T0.5mW-P40ishmW+27.6dBm-wlen1552_1556_0.025-2.tsv')
d['M3_r3s1b_out']     = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T1.2mW-P40ishmW+27.6dBm-wlen1552_1556_0.025.tsv')

d['M3_r3s2_out']      = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T1mW-P40ishmW+27.6dBm-wlen1552_1556_0.025.tsv')
d['M3_r3s2_out-2']    = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T1mW-P40ishmW+27.6dBm-wlen1552_1556_0.025-2.tsv')
d['M3_r3s3_out']      = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T2mW-P40ishmW+27.6dBm-wlen1552_1556_0.025.tsv')
d['M3_r3s3_out-2']    = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T2mW-P40ishmW+27.6dBm-wlen1552_1556_0.025-2.tsv')
d['M3_r3s4_out']      = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T3mW-P40ishmW+27.6dBm-wlen1552_1556_0.025.tsv')
d['M3_r3s4_out-2']    = np.loadtxt(path2+'h1700/'+'2017_11_16-M3-T3mW-P40ishmW+27.6dBm-wlen1552_1556_0.025-2.tsv')

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

mi = (np.min(d['M3_r1s1_out'][:,2]) + np.min(d['M3_r1s3_out'][:,2]))/2.0

ax1.plot(d['M3_r1s1_out'][:,0],  d['M3_r1s1_out'][:,2]-mi,  label='out 4mW, rise', ls='-')
ax1.plot(d['M3_r1s2_out'][:,0],  d['M3_r1s2_out'][:,2]-mi,  label='out 4mW, rise', ls='-')
ax1.plot(d['M3_r1s3_out'][:,0],  d['M3_r1s3_out'][:,2]-mi,  label='out 4mW, rise', ls='-')

ax1.set_title( r'M3 i1o1, first run (h1000)', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

del mi

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

ax1.plot(d['M3_r2_tunics1'][:,0],  d['M3_r2_tunics1'][:,1],  label='tunics 1mW (OSA)', ls='-')
ax1.plot(d['M3_r2_tunics2'][:,0],  d['M3_r2_tunics2'][:,1],  label='tunics 0.5mW (OSA)', ls='-')
ax1.plot(d['M3_r2s1_pump'][:,0],   d['M3_r2s1_pump'][:,1],   label='tunics 0.5mW,\npump 38.3mW (OSA)', ls='-')
ax1.plot(d['M3_r2s1_pump-2'][:,0],   d['M3_r2s1_pump-2'][:,1],   label='tunics 0.5mW,\npump 38.2mW (OSA)', ls='-')
ax1.plot(d['M3_r2s1_pump-3'][:,0],   d['M3_r2s1_pump-3'][:,1],   label='tunics 0.5mW,\npump 38.08mW (OSA)', ls='-')
ax1.plot(d['M3_r2s2_pump'][:,0],   d['M3_r2s2_pump'][:,1],   label='tunics 0.5mW,\npump 37.98mW (OSA)', ls='-')

ax1.set_title( r'Tunics spectra, OSA', fontsize=16)
ax1.set_xlabel(r'Wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

ax1.set_ylim([-0.0125,0.2125])

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

print(d['M3_r2_tunics1'][d['M3_r2_tunics1'][:,1]==max(d['M3_r2_tunics1'][:,1]),0],' nm')
print(d['M3_r2_tunics2'][d['M3_r2_tunics2'][:,1]==max(d['M3_r2_tunics2'][:,1]),0],' nm')
print(d['M3_r2s1_pump'][d['M3_r2s1_pump'][:,1]==max(d['M3_r2s1_pump'][0:250,1]),0],' nm')
print(d['M3_r2s1_pump-2'][d['M3_r2s1_pump-2'][:,1]==max(d['M3_r2s1_pump-2'][0:250,1]),0],' nm')
print(d['M3_r2s1_pump-3'][d['M3_r2s1_pump-3'][:,1]==max(d['M3_r2s1_pump-3'][400:-1,1]),0],' nm')
print(d['M3_r2s2_pump'][d['M3_r2s2_pump'][:,1]==max(d['M3_r2s2_pump'][400:-1,1]),0],' nm')
# Out:
# [ 1551.28]  nm
# [ 1551.29  1551.3 ]  nm
# [ 1551.27]  nm
# [ 1551.28]  nm
# [ 1554.1]  nm
# [ 1554.09]  nm

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

noise = np.mean(d['M3_r2_noise'][:,2])

ax1.plot(d['M3_r2_resonance1'][:,0]-3+1.29,  d['M3_r2_resonance1'][:,2]-noise,  label='tunics 1mW', ls='-')
ax1.plot(d['M3_r2_resonance2'][:,0]-3+1.29,  d['M3_r2_resonance2'][:,2]-noise,  label='tunics 1mW', ls='-')
ax1.plot(d['M3_r2_resonance3'][:,0]-3+1.29,  d['M3_r2_resonance3'][:,2]-noise,  label='tunics 0.5mW', ls='-')
ax1.plot(d['M3_r2_noise'][:,0]-3+1.29,       d['M3_r2_noise'][:,1]-noise,       label='Ge noise', ls='-')

ax1.set_title( r'M3 first output resonance', fontsize=16)
ax1.set_xlabel(r'Correct wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

max1  = d['M3_r2_resonance1'][d['M3_r2_resonance1'][:,2]==max(d['M3_r2_resonance1'][:,2]),0]-3+1.29
temp1 = d['M3_r2_resonance1'][d['M3_r2_resonance1'][:,2]>=max(d['M3_r2_resonance1'][:,2]/2.0),0]-3+1.29
print(max1,'nm',temp1[0],'nm, ',temp1[-1],'nm')
print(max1/(temp1[-1]-temp1[0]))

max2  = d['M3_r2_resonance2'][d['M3_r2_resonance2'][:,2]==max(d['M3_r2_resonance2'][:,2]),0]-3+1.29
temp2 = d['M3_r2_resonance2'][d['M3_r2_resonance2'][:,2]>=max(d['M3_r2_resonance2'][:,2]/2.0),0]-3+1.29
print(max2,'nm',temp2[0],'nm, ',temp2[-1],'nm')
print(max2/(temp2[-1]-temp2[0]))

max3  = d['M3_r2_resonance3'][d['M3_r2_resonance3'][:,2]==max(d['M3_r2_resonance3'][:,2]),0]-3+1.29
temp3 = d['M3_r2_resonance3'][d['M3_r2_resonance3'][:,2]>=max(d['M3_r2_resonance3'][:,2]/2.0),0]-3+1.29
print(max3,'nm',temp3[0],'nm, ',temp3[-1],'nm')
print(max3/(temp3[-1]-temp3[0]))

Q_avg = (max1/(temp1[-1]-temp1[0])+max2/(temp2[-1]-temp2[0])+max3/(temp3[-1]-temp3[0]))/3.0
print('\nAverage quality factor Q is: ', Q_avg)

del max1, temp1, max2, temp2, max3, temp3, Q_avg

print()
# Out:
# [ 1552.01] nm 1551.69 nm,  1552.34 nm
# [ 2387.70769231]
# [ 1552.] nm 1551.69 nm,  1552.34 nm
# [ 2387.69230769]
# [ 1551.97] nm 1551.65 nm,  1552.31 nm
# [ 2351.46969697]
#
# Average quality factor Q is:  [ 2375.62323232]

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

noise = np.mean(d['M3_r2_noise'][:,1])

ax1.plot(d['M3_r1s1_out'][:,0]-1.71,  d['M3_r1s1_out'][:,2]-noise,  label='out 4mW, rise', ls='-')
ax1.plot(d['M3_r1s2_out'][:,0]-1.71,  d['M3_r1s2_out'][:,2]-noise,  label='out 4mW, rise', ls='-')
ax1.plot(d['M3_r1s3_out'][:,0]-1.71,  d['M3_r1s3_out'][:,2]-noise,  label='out 4mW, rise', ls='-')

ax1.plot(d['M3_r2s1_out'][:,0]-1.71,  d['M3_r2s1_out'][:,2]-noise,  label='tunics 0.5mW', ls='-')
ax1.plot(d['M3_r2s2_out'][:,0]-1.71,  d['M3_r2s2_out'][:,2]-noise,  label='tunics 0.5mW', ls='-')
#ax1.plot(d['M3_r2s3_out'][:,0]-1.71,  d['M3_r2s3_out'][:,2]-noise,  label='tunics 4.0mW', ls='-')

ax1.set_title( r'M3 i1o1, second run (h1400)', fontsize=16)
ax1.set_xlabel(r'Correct wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
fig = plt.figure(figsize=(3*6.4, 2*4.8)) # default = 6.4, 4.8
ax1 = fig.add_subplot(111)

noise = np.mean(d['M3_r2_noise'][:,1])

ax1.plot(d['M3_r3s1_out'][:,0]-1.71,  d['M3_r3s1_out'][:,2]-noise,  label='out 0.5mW, 1', ls='-')
ax1.plot(d['M3_r3s1_out-2'][:,0]-1.71,  d['M3_r3s1_out-2'][:,2]-noise,  label='out 0.5mW, 2', ls='-')

ax1.plot(d['M3_r3s1b_out'][:,0]-1.71,  d['M3_r3s1b_out'][:,2]-noise,  label='out 1.2mW', ls='-')

ax1.plot(d['M3_r3s2_out'][:,0]-1.71,  d['M3_r3s2_out'][:,2]-noise,  label='out 1mW, 1', ls='-')
ax1.plot(d['M3_r3s2_out-2'][:,0]-1.71,  d['M3_r3s2_out-2'][:,2]-noise,  label='out 1mW, 2', ls='-')
ax1.plot(d['M3_r3s3_out'][:,0]-1.71,  d['M3_r3s3_out'][:,2]-noise,  label='out 2mW, 1', ls='-')
ax1.plot(d['M3_r3s3_out-2'][:,0]-1.71,  d['M3_r3s3_out-2'][:,2]-noise,  label='out 2mW, 2', ls='-')
ax1.plot(d['M3_r3s4_out'][:,0]-1.71,  d['M3_r3s4_out'][:,2]-noise,  label='out 3mW, 1', ls='-')
ax1.plot(d['M3_r3s4_out-2'][:,0]-1.71,  d['M3_r3s4_out-2'][:,2]-noise,  label='out 3mW, 2', ls='-')

ax1.set_title( r'M3 i1o1, third run (h1700)', fontsize=16)
ax1.set_xlabel(r'Correct wavelength $\lambda$ $[nm]$', fontsize=16)
ax1.set_ylabel(r'Output intensity $[mW]$', fontsize=16)

box = ax1.get_position()
ax1.set_position([box.x0, box.y0, box.width * 0.8, box.height])

legend = ax1.legend(loc='center left', fontsize=16, bbox_to_anchor=(1, 0.5))

plt.show()
plt.close()

# %%
def BaseJumpFinder(data_x, data_y):
    Dy = np.diff(data_y)
    maxDy = max(Dy)
    return Dy.tolist().index(maxDy)

# %%
print(d['M3P41mW_a_out'][BaseJumpFinder(d['M3P41mW_a_out'][:,0], d['M3P41mW_a_out'][:,2]-noise),2]-noise)

print(d['M3_r1s1_out'][BaseJumpFinder(d['M3_r1s1_out'][:,0], d['M3_r1s1_out'][:,2]-noise),2]-noise)
print(d['M3_r1s3_out'][BaseJumpFinder(d['M3_r1s3_out'][:,0], d['M3_r1s3_out'][:,2]-noise),2]-noise)

print(d['M3_r2s1_out'][BaseJumpFinder(d['M3_r2s1_out'][:,0], d['M3_r2s1_out'][:,2]-noise),2]-noise)

print(d['M3_r3s1b_out'][BaseJumpFinder(d['M3_r3s1b_out'][:,0], d['M3_r3s1b_out'][:,2]-noise),2]-noise)
print(d['M3_r3s4_out-2'][BaseJumpFinder(d['M3_r3s4_out-2'][:,0], d['M3_r3s4_out-2'][:,2]-noise),2]-noise)
# Out:
# 1.0706531825
# 1.0841981825
# 1.0796451825
# 1.0295491825
# 1.0475711825
# 0.9657071825
